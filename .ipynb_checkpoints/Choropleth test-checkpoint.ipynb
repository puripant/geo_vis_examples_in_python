# %%
import geopandas as gpd
import matplotlib.pyplot as plt

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
import pandas as pd
provinces = pd.read_csv(r'data/provinces.csv')
provinces
# Out:
#     id             name                   name_en      area
# 0   10    กรุงเทพมหานคร                   BANGKOK   1568.95
# 1   11      สมุทรปราการ              SAMUT PRAKAN    960.09
# 2   12          นนทบุรี                NONTHABURI    633.25
# 3   13         ปทุมธานี              PATHUM THANI   1520.06
# 4   14  พระนครศรีอยุธยา  PHRA NAKHON SI AYUTTHAYA   2534.07
# 5   15          อ่างทอง                 ANG THONG    948.68
# 6   16           ลพบุรี                  LOP BURI   6290.80
# 7   17        สิงห์บุรี                 SING BURI    831.57
# 8   18           ชัยนาท                  CHAI NAT   2463.64
# 9   19          สระบุรี                  SARABURI   3504.53
# 10  20           ชลบุรี                 CHON BURI   4469.40
# 11  21            ระยอง                    RAYONG   3711.09
# 12  22         จันทบุรี               CHANTHABURI   6367.85
# 13  23             ตราด                      TRAT   2889.18
# 14  24       ฉะเชิงเทรา              CHACHOENGSAO   5238.31
# 15  25       ปราจีนบุรี              PRACHIN BURI   4983.17
# 16  26          นครนายก              NAKHON NAYOK   2143.23
# 17  27          สระแก้ว                   SA KAEO   6899.52
# 18  30       นครราชสีมา         NAKHON RATCHASIMA  20708.17
# 19  31        บุรีรัมย์                  BURI RAM  10128.03
# 20  32         สุรินทร์                     SURIN   8855.55
# 21  33         ศรีสะเกษ                 SI SA KET   8933.23
# 22  34      อุบลราชธานี          UBON RATCHATHANI  15641.28
# 23  35            ยโสธร                  YASOTHON   4127.36
# 24  36          ชัยภูมิ                CHAIYAPHUM  12674.12
# 25  37       อำนาจเจริญ             AMNAT CHAROEN   3272.03
# 26  38           บึงกาฬ                 NONG KHAI   4019.12
# 27  39      หนองบัวลำภู           NONG BUA LAMPHU   4134.40
# 28  40          ขอนแก่น                 KHON KAEN  10643.38
# 29  41         อุดรธานี                UDON THANI  11094.85
# ..  ..              ...                       ...       ...
# 47  60        นครสวรรค์              NAKHON SAWAN   9504.41
# 48  61        อุทัยธานี               UTHAI THANI   6651.92
# 49  62        กำแพงเพชร            KAMPHAENG PHET   8619.16
# 50  63              ตาก                       TAK  17241.82
# 51  64          สุโขทัย                 SUKHOTHAI   6689.36
# 52  65         พิษณุโลก               PHITSANULOK  10612.84
# 53  66           พิจิตร                   PHICHIT   4320.79
# 54  67        เพชรบูรณ์                PHETCHABUN  12421.40
# 55  70          ราชบุรี                RATCHABURI   5179.39
# 56  71        กาญจนบุรี              KANCHANABURI  19422.04
# 57  72       สุพรรณบุรี               SUPHAN BURI   5406.44
# 58  73           นครปฐม             NAKHON PATHOM   2140.80
# 59  74        สมุทรสาคร              SAMUT SAKHON    864.14
# 60  75      สมุทรสงคราม           SAMUT SONGKHRAM    409.05
# 61  76         เพชรบุรี               PHETCHABURI   6165.56
# 62  77  ประจวบคีรีขันธ์       PRACHUAP KHIRI KHAN   6437.23
# 63  80    นครศรีธรรมราช       NAKHON SI THAMMARAT   9861.78
# 64  81           กระบี่                     KRABI   4869.32
# 65  82            พังงา                  PHANGNGA   4106.74
# 66  83           ภูเก็ต                    PHUKET    553.51
# 67  84     สุราษฎร์ธานี               SURAT THANI  13183.90
# 68  85            ระนอง                    RANONG   3245.17
# 69  86            ชุมพร                  CHUMPHON   5997.03
# 70  90            สงขลา                  SONGKHLA   7857.23
# 71  91             สตูล                     SATUN   2711.39
# 72  92             ตรัง                     TRANG   4882.19
# 73  93           พัทลุง               PHATTHALUNG   3764.62
# 74  94          ปัตตานี                   PATTANI   1953.05
# 75  95             ยะลา                      YALA   4482.17
# 76  96         นราธิวาส                NARATHIWAT   4483.92
#
# [77 rows x 4 columns]

# %%
world.plot(column='continent', figsize=(30, 10))
plt.axis('off')
# Out:
# (-197.99999999999994,
#  198.00000000000014,
#  -98.682256500000037,
#  92.327386500000031)

# %%
world.plot(column='pop_est', cmap='PuOr', scheme='quantiles', figsize=(30, 10))
plt.axis('off')

world['pop_est']
scale = plt.Normalize().autoscale(world['pop_est'])
legend = plt.cm.ScalarMappable(cmap='PuOr', norm=scale)
legend._A = []
plt.colorbar(legend)

# %%
base = world.plot(color='lightgray', edgecolor='0.8', linewidth=1, figsize=(30, 10))
cities.plot(ax=base, marker='o', color='red', markersize=10)
plt.axis('off')
# Out:
# (-197.99999999999994,
#  198.00000000000014,
#  -98.682256500000037,
#  92.327386500000031)
